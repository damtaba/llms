# %% [markdown]
# # Paquetes y seteo

# %%
# !pip install -qU "langchain[openai]"

# %%
import getpass
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage

load_dotenv(".env")
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
LANGSMITH_TRACING= True
LANGSMITH_API_KEY = os.getenv("LANGSMITH_API_KEY")

# %%
OPENAI_API_KEY
# Out:
# ''

# %%
model = init_chat_model("gpt-4o-mini", model_provider="openai")

# %%
model.invoke([HumanMessage(content="What's my name")])
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_sync\http11.py:86, in HTTP11Connection.handle_request(self, request)
#      83 with Trace(
#      84     "send_request_headers", logger, request, kwargs
#      85 ) as trace:
# ---> 86     self._send_request_headers(**kwargs)
#      87 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_sync\http11.py:144, in HTTP11Connection._send_request_headers(self, request)
#     142 timeout = timeouts.get("write", None)
# --> 144 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     145     event = h11.Request(
#     146         method=request.method,
#     147         target=request.url.target,
#     148         headers=request.headers,
#     149     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1009, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1008 try:
# -> 1009     response = self._client.send(
#    1010         request,
#    1011         stream=stream or self._should_stream_response_body(request=request),
#    1012         **kwargs,
#    1013     )
#    1014 except httpx.TimeoutException as err:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.invoke([HumanMessage(content="What's my name")])
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:285, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     274 def invoke(
#     275     self,
#     276     input: LanguageModelInput,
#    (...)    280     **kwargs: Any,
#     281 ) -> BaseMessage:
#     282     config = ensure_config(config)
#     283     return cast(
#     284         ChatGeneration,
# --> 285         self.generate_prompt(
#     286             [self._convert_input(input)],
#     287             stop=stop,
#     288             callbacks=config.get("callbacks"),
#     289             tags=config.get("tags"),
#     290             metadata=config.get("metadata"),
#     291             run_name=config.get("run_name"),
#     292             run_id=config.pop("run_id", None),
#     293             **kwargs,
#     294         ).generations[0][0],
#     295     ).message
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:861, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     853 def generate_prompt(
#     854     self,
#     855     prompts: list[PromptValue],
#    (...)    858     **kwargs: Any,
#     859 ) -> LLMResult:
#     860     prompt_messages = [p.to_messages() for p in prompts]
# --> 861     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:691, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     688 for i, m in enumerate(messages):
#     689     try:
#     690         results.append(
# --> 691             self._generate_with_cache(
#     692                 m,
#     693                 stop=stop,
#     694                 run_manager=run_managers[i] if run_managers else None,
#     695                 **kwargs,
#     696             )
#     697         )
#     698     except BaseException as e:
#     699         if run_managers:
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:926, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     924 else:
#     925     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 926         result = self._generate(
#     927             messages, stop=stop, run_manager=run_manager, **kwargs
#     928         )
#     929     else:
#     930         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:800, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     798     generation_info = {"headers": dict(raw_response.headers)}
#     799 else:
# --> 800     response = self.client.create(**payload)
#     801 return self._create_chat_result(response, generation_info)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)    876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1296, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1282 def post(
#    1283     self,
#    1284     path: str,
#    (...)   1291     stream_cls: type[_StreamT] | None = None,
#    1292 ) -> ResponseT | _StreamT:
#    1293     opts = FinalRequestOptions.construct(
#    1294         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1295     )
# -> 1296     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:973, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     970 else:
#     971     retries_taken = 0
# --> 973 return self._request(
#     974     cast_to=cast_to,
#     975     options=options,
#     976     stream=stream,
#     977     stream_cls=stream_cls,
#     978     retries_taken=retries_taken,
#     979 )
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1033, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1030 log.debug("Encountered Exception", exc_info=True)
#    1032 if remaining_retries > 0:
# -> 1033     return self._retry_request(
#    1034         input_options,
#    1035         cast_to,
#    1036         retries_taken=retries_taken,
#    1037         stream=stream,
#    1038         stream_cls=stream_cls,
#    1039         response_headers=None,
#    1040     )
#    1042 log.debug("Raising connection error")
#    1043 raise APIConnectionError(request=request) from err
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1111, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1107 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1108 # different thread if necessary.
#    1109 time.sleep(timeout)
# -> 1111 return self._request(
#    1112     options=options,
#    1113     cast_to=cast_to,
#    1114     retries_taken=retries_taken + 1,
#    1115     stream=stream,
#    1116     stream_cls=stream_cls,
#    1117 )
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1033, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1030 log.debug("Encountered Exception", exc_info=True)
#    1032 if remaining_retries > 0:
# -> 1033     return self._retry_request(
#    1034         input_options,
#    1035         cast_to,
#    1036         retries_taken=retries_taken,
#    1037         stream=stream,
#    1038         stream_cls=stream_cls,
#    1039         response_headers=None,
#    1040     )
#    1042 log.debug("Raising connection error")
#    1043 raise APIConnectionError(request=request) from err
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1111, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1107 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1108 # different thread if necessary.
#    1109 time.sleep(timeout)
# -> 1111 return self._request(
#    1112     options=options,
#    1113     cast_to=cast_to,
#    1114     retries_taken=retries_taken + 1,
#    1115     stream=stream,
#    1116     stream_cls=stream_cls,
#    1117 )
#
# File c:\Users\dario\Documents\GitHub\llms\.venv\Lib\site-packages\openai\_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1033         return self._retry_request(
#    1034             input_options,
#    1035             cast_to,
#    (...)   1039             response_headers=None,
#    1040         )
#    1042     log.debug("Raising connection error")
# -> 1043     raise APIConnectionError(request=request) from err
#    1045 log.debug(
#    1046     'HTTP Response: %s %s "%i %s" %s',
#    1047     request.method,
#    (...)   1051     response.headers,
#    1052 )
#    1053 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
